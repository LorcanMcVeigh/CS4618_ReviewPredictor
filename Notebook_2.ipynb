# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Series</h1>

# %%
s = pd.Series([2,4,-12,0,2])

# %%
s
# Out:
# 0     2
# 1     4
# 2   -12
# 3     0
# 4     2
# dtype: int64

# %%
s.shape
# Out:
# (5,)

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([  2,   4, -12,   0,   2])

# %%
s[3]
# Out:
# 0

# %%
s[1:3]
# Out:
# 1     4
# 2   -12
# dtype: int64

# %%
s[[True,True,False,False,True]]
# Out:
# 0    2
# 1    4
# 4    2
# dtype: int64

# %%
s * 2
# Out:
# 0     4
# 1     8
# 2   -24
# 3     0
# 4     4
# dtype: int64

# %%
s > 0
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
s[s > 0]
# Out:
# 0    2
# 1    4
# 4    2
# dtype: int64

# %%
s.sum
# Out:
# <bound method Series.sum of 0     2
# 1     4
# 2   -12
# 3     0
# 4     2
# dtype: int64>

# %%
s.sum()
# Out:
# -4

# %%
s.mean()
# Out:
# -0.8

# %%
s.unique()
# Out:
# array([  2,   4, -12,   0])

# %% [markdown]
# <h1>Data Frame</h1>

# %%
df = pd.read_csv("datasets/dataset_stop_and_searchA.csv")

# %%
df
# Out:
#     Gender      Age                                  Suspect-ethnicity  \
# 0     Male      NaN                    Other ethnic group - Not stated
# 1     Male    18-24                    Other ethnic group - Not stated
# 2     Male    18-24                    Other ethnic group - Not stated
# 3     Male    18-24                    Other ethnic group - Not stated
# 4     Male    18-24                    Other ethnic group - Not stated
# 5     Male    18-24                    Other ethnic group - Not stated
# 6     Male    18-24                 White - Any other White background
# 7     Male    25-34                       Asian/Asian British - Indian
# 8     Male    18-24                 White - Any other White background
# 9     Male      NaN        Other ethnic group - Any other ethnic group
# 10    Male      NaN                 White - Any other White background
# 11  Female    18-24  Black/African/Caribbean/Black British - Any ot...
# ...

# %%
df.describe(include='all')
# Out:
#        Gender    Age                Suspect-ethnicity Officer-ethnicity  \
# count      40     36                               40                40
# unique      2      4                               10                 4
# top      Male  18-24  Other ethnic group - Not stated             Black
# freq       37     22                               12                16
#
#         Object-of-search                       Outcome
# count                 40                            40
# unique                 4                             3
# top     Controlled drugs  A no further action disposal
# freq                  22                            24

# %%
df.shape
# Out:
# (40, 6)

# %%
df.dtypes
# Out:
# Gender               object
# Age                  object
# Suspect-ethnicity    object
# Officer-ethnicity    object
# Object-of-search     object
# Outcome              object
# dtype: object

# %%
df['Suspect-ethnicity']
# Out:
# 0                       Other ethnic group - Not stated
# 1                       Other ethnic group - Not stated
# 2                       Other ethnic group - Not stated
# 3                       Other ethnic group - Not stated
# 4                       Other ethnic group - Not stated
# 5                       Other ethnic group - Not stated
# 6                    White - Any other White background
# 7                          Asian/Asian British - Indian
# 8                    White - Any other White background
# 9           Other ethnic group - Any other ethnic group
# 10                   White - Any other White background
# 11    Black/African/Caribbean/Black British - Any ot...
# 12      Black/African/Caribbean/Black British - African
# 13                   White - Any other White background
# 14                   White - Any other White background
# 15    Black/African/Caribbean/Black British - Caribbean
# 16                      Other ethnic group - Not stated
# ...

# %%
df['Suspect-ethnicity'].unique()
# Out:
# array(['Other ethnic group - Not stated',
#        'White - Any other White background',
#        'Asian/Asian British - Indian',
#        'Other ethnic group - Any other ethnic group',
#        'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#        'Black/African/Caribbean/Black British - African',
#        'Black/African/Caribbean/Black British - Caribbean',
#        'Mixed/Multiple ethnic groups - White and Black African',
#        'White - English/Welsh/Scottish/Northern Irish/British',
#        'Asian/Asian British - Any other Asian background'], dtype=object)

# %%
df[['Suspect-ethnicity', 'Officer-ethnicity']]
# Out:
#                                     Suspect-ethnicity Officer-ethnicity
# 0                     Other ethnic group - Not stated             Black
# 1                     Other ethnic group - Not stated             Asian
# 2                     Other ethnic group - Not stated             Asian
# 3                     Other ethnic group - Not stated             Asian
# 4                     Other ethnic group - Not stated             Asian
# 5                     Other ethnic group - Not stated             White
# 6                  White - Any other White background             White
# 7                        Asian/Asian British - Indian             Asian
# 8                  White - Any other White background             White
# 9         Other ethnic group - Any other ethnic group             Black
# 10                 White - Any other White background             White
# 11  Black/African/Caribbean/Black British - Any ot...             Black
# ...

# %%
df.loc[4]
# Out:
# Gender                                          Male
# Age                                            18-24
# Suspect-ethnicity    Other ethnic group - Not stated
# Officer-ethnicity                              Asian
# Object-of-search                    Controlled drugs
# Outcome                         Community resolution
# Name: 4, dtype: object

# %%
df['Officer-ethnicity'] == 'Black'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21    False
# 22     True
# 23     True
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34     True
# 35     True
# 36    False
# 37    False
# 38    False
# 39     True
# Name: Officer-ethnicity, dtype: bool

# %%
df[df['Officer-ethnicity'] == 'Black']
# Out:
#     Gender    Age                                  Suspect-ethnicity  \
# 0     Male    NaN                    Other ethnic group - Not stated
# 9     Male    NaN        Other ethnic group - Any other ethnic group
# 11  Female  18-24  Black/African/Caribbean/Black British - Any ot...
# 12    Male  10-17    Black/African/Caribbean/Black British - African
# 15    Male  25-34  Black/African/Caribbean/Black British - Caribbean
# 18    Male  25-34  Black/African/Caribbean/Black British - Any ot...
# 19    Male  25-34                    Other ethnic group - Not stated
# 20    Male  18-24  Mixed/Multiple ethnic groups - White and Black...
# 22  Female  18-24  White - English/Welsh/Scottish/Northern Irish/...
# 23    Male  18-24    Black/African/Caribbean/Black British - African
# 25    Male  18-24  Black/African/Caribbean/Black British - Caribbean
# 28    Male  18-24  Black/African/Caribbean/Black British - Any ot...
# 30    Male  18-24  Black/African/Caribbean/Black British - Any ot...
# ...

# %%
df[ (df['Officer-ethnicity'] == 'Black') & (df['Object-of-search'] == 'Stolen goods') ]
# Out:
#     Gender    Age                                  Suspect-ethnicity  \
# 11  Female  18-24  Black/African/Caribbean/Black British - Any ot...
# 30    Male  18-24  Black/African/Caribbean/Black British - Any ot...
#
#    Officer-ethnicity Object-of-search                       Outcome
# 11             Black     Stolen goods  A no further action disposal
# 30             Black     Stolen goods                        Arrest

# %% [markdown]
# <h2>Exercise</h2>
# Write a line of python to find how many times the officer were looking for 'Stolen goods'

# %%
timeit (df['Object-of-search'] == 'Stolen goods').sum()
# Out:
# 456 µs ± 4.32 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
timeit len(df[df['Object-of-search'] == 'Stolen goods'])
# Out:
# 798 µs ± 5.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
m,n = df.shape

# %%
np.random.permutation(m)
# Out:
# array([ 1,  9, 12, 22, 27,  7, 13, 10, 26, 11, 19, 33, 14, 35,  0, 38,  3,
#        31, 39,  4, 37, 24, 34, 30, 15,  8, 23, 32,  5, 21, 18,  2, 25, 20,
#        36,  6, 17, 29, 16, 28])

# %%
df.take(np.random.permutation(m))
# Out:
#     Gender      Age                                  Suspect-ethnicity  \
# 22  Female    18-24  White - English/Welsh/Scottish/Northern Irish/...
# 33    Male    18-24  White - English/Welsh/Scottish/Northern Irish/...
# 16    Male    25-34                    Other ethnic group - Not stated
# 28    Male    18-24  Black/African/Caribbean/Black British - Any ot...
# 12    Male    10-17    Black/African/Caribbean/Black British - African
# 38    Male    18-24   Asian/Asian British - Any other Asian background
# 11  Female    18-24  Black/African/Caribbean/Black British - Any ot...
# 14    Male  over 34                 White - Any other White background
# 0     Male      NaN                    Other ethnic group - Not stated
# 37    Male    18-24                    Other ethnic group - Not stated
# 29    Male    18-24   Asian/Asian British - Any other Asian background
# 9     Male      NaN        Other ethnic group - Any other ethnic group
# ...

# %%
df = df.take(np.random.permutation(m))

# %%
df
# Out:
#     Gender      Age                                  Suspect-ethnicity  \
# 34    Male    10-17                    Other ethnic group - Not stated
# 16    Male    25-34                    Other ethnic group - Not stated
# 7     Male    25-34                       Asian/Asian British - Indian
# 23    Male    18-24    Black/African/Caribbean/Black British - African
# 24    Male    25-34  White - English/Welsh/Scottish/Northern Irish/...
# 13    Male  over 34                 White - Any other White background
# 0     Male      NaN                    Other ethnic group - Not stated
# 39    Male    18-24  Black/African/Caribbean/Black British - Any ot...
# 27  Female    18-24   Asian/Asian British - Any other Asian background
# 5     Male    18-24                    Other ethnic group - Not stated
# 20    Male    18-24  Mixed/Multiple ethnic groups - White and Black...
# 3     Male    18-24                    Other ethnic group - Not stated
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     Gender      Age                                  Suspect-ethnicity  \
# 0     Male    10-17                    Other ethnic group - Not stated
# 1     Male    25-34                    Other ethnic group - Not stated
# 2     Male    25-34                       Asian/Asian British - Indian
# 3     Male    18-24    Black/African/Caribbean/Black British - African
# 4     Male    25-34  White - English/Welsh/Scottish/Northern Irish/...
# 5     Male  over 34                 White - Any other White background
# 6     Male      NaN                    Other ethnic group - Not stated
# 7     Male    18-24  Black/African/Caribbean/Black British - Any ot...
# 8   Female    18-24   Asian/Asian British - Any other Asian background
# 9     Male    18-24                    Other ethnic group - Not stated
# 10    Male    18-24  Mixed/Multiple ethnic groups - White and Black...
# 11    Male    18-24                    Other ethnic group - Not stated
# ...

# %% [markdown]
# <h1>Main Exercise</h1>

# %%
df = pd.read_csv("datasets/dataset_stop_and_searchB.csv")

# %%
df.shape
# Out:
# (169427, 6)

# %% [markdown]
# Are the met racist?

# %%
df.describe(include='all')
# Out:
#         Gender     Age                                  Suspect-ethnicity  \
# count   167396  154380                                             167442
# unique       4       6                                                 18
# top       Male   18-24  White - English/Welsh/Scottish/Northern Irish/...
# freq    156580   60252                                              30536
#
#        Officer-ethnicity  Object-of-search                       Outcome
# count             166379            168899                        169427
# unique                 5                 9                             8
# top                Black  Controlled drugs  A no further action disposal
# freq               69333             95770                        125814

# %%
df[['Suspect-ethnicity', 'Officer-ethnicity']]
# Out:
#                                         Suspect-ethnicity Officer-ethnicity
# 0                         Other ethnic group - Not stated             Black
# 1                         Other ethnic group - Not stated             Asian
# 2                         Other ethnic group - Not stated             Asian
# 3                         Other ethnic group - Not stated             Asian
# 4                         Other ethnic group - Not stated             Asian
# 5                         Other ethnic group - Not stated             White
# 6                      White - Any other White background             White
# 7                            Asian/Asian British - Indian             Asian
# 8                      White - Any other White background             White
# 9             Other ethnic group - Any other ethnic group             Black
# 10                     White - Any other White background             White
# ...

# %%
(df['Officer-ethnicity'] == df['Suspect-ethnicity'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 169397    False
# 169398    False
# 169399    False
# 169400    False
# 169401    False
# 169402    False
# 169403    False
# 169404    False
# 169405    False
# 169406    False
# 169407    False
# 169408    False
# 169409    False
# 169410    False
# 169411    False
# 169412    False
# 169413    False
# 169414    False
# 169415    False
# 169416    False
# 169417    False
# 169418    False
# 169419    False
# 169420    False
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-71-7a9f67279412> in <module>
# ----> 1 df.groupby(['Suspect-ethnicity']).mean()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
# ...

# %%
df['Suspect-ethnicity'].unique()
# Out:
# array(['Other ethnic group - Not stated',
#        'White - Any other White background',
#        'Asian/Asian British - Indian',
#        'Other ethnic group - Any other ethnic group',
#        'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#        'Black/African/Caribbean/Black British - African',
#        'Black/African/Caribbean/Black British - Caribbean',
#        'Mixed/Multiple ethnic groups - White and Black African',
#        'White - English/Welsh/Scottish/Northern Irish/British',
#        'Asian/Asian British - Any other Asian background',
#        'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#        'Asian/Asian British - Bangladeshi',
#        'Asian/Asian British - Pakistani',
#        'Mixed/Multiple ethnic groups - White and Black Caribbean', nan,
#        'White - Irish', 'Mixed/Multiple ethnic groups - White and Asian',
#        'Asian/Asian British - Chinese', 'Self-defined ethnicity'],
# ...

# %%
s = df.groupby(['Suspect-ethnicity']).describe()

# %%
s['Officer-ethnicity']
# Out:
#                                                     count unique  \
# Suspect-ethnicity
# Asian/Asian British - Any other Asian background    11025      4
# Asian/Asian British - Bangladeshi                    7728      4
# Asian/Asian British - Chinese                         276      4
# Asian/Asian British - Indian                         2697      4
# Asian/Asian British - Pakistani                      3074      4
# Black/African/Caribbean/Black British - African     16715      4
# Black/African/Caribbean/Black British - Any oth...  22024      4
# Black/African/Caribbean/Black British - Caribbean   11864      4
# Mixed/Multiple ethnic groups - Any other Mixed/...   2985      4
# Mixed/Multiple ethnic groups - White and Asian        404      4
# Mixed/Multiple ethnic groups - White and Black ...    643      4
# Mixed/Multiple ethnic groups - White and Black ...   1977      4
# Other ethnic group - Any other ethnic group          4380      4
# ...

# %%
race_white = \
(df['Suspect-ethnicity'] == 'White - Any other White background') | \
(df['Suspect-ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British') | \
(df['Suspect-ethnicity'] == 'White - Irish')

# %%
race_white = race_white.sum()

# %%
race_known = \
(df['Suspect-ethnicity'] != 'Other ethnic group - Not stated') & \
(df['Suspect-ethnicity'] != 'Other ethnic group - Any other ethnic group')

# %%
race_white * 100 /race_known.sum()
# Out:
# 38.32540395634178

# %% [markdown]
# Yes they are racist
